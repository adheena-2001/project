# %%
import matplotlib.pyplot as plt
x=[5,2,3,4]
y=[8,9,10,11]
plt.plot(x,y,"*")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[5,2,3,4]
y=[8,9,10,11]
plt.plot(x,y)
plt.show()

# %%
y=[8,9,10,11]
plt.plot(y)

# %%
import numpy as np
ypoints=np.array([1,5,2,7])
plt.plot(ypoints,"*:r")#*-point,:-doted lines,r=red color

# %%
plt.plot(ypoints,linestyle='dotted',color='r')

# %%
plt.plot(ypoints,linewidth='20')

# %%
x1=[1,2,3,4]
y1=[4,5,6,7]
x2=[8,9,0,1]
y2=[3,4,5,6]
plt.plot(x1,y1)
plt.plot(x2,y2)

# %%
x=[150,155,160,162]
y=[45,50,51,53]
plt.plot(x,y)
plt.xlabel("Height in cm")
plt.ylabel("Weight in kg")
plt.title("Height vs weight")
# Out:
# Text(0.5, 1.0, 'Height vs weight')
